# %% [markdown]
# # Split Training Model For The Hybrid Autoencoder

# %% [markdown]
# ### Library imports.

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, losses
from sklearn.metrics import accuracy_score, precision_score, recall_score

import matplotlib.pyplot as plt
import numpy as np

import os
# Out:
# 2022-07-03 15:22:12.732896: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-07-03 15:22:12.732918: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
# Number of modes
modes = 1

# tt
train_state_select = 4

# Cutoff dimension (number of Fock states)
cutoff_dim = 5

# Input vector length.
input_len = 5

# Number of layers (depth)
Qlayers = 25

# Number of steps in optimization routine performing gradient descent
reps = 500

# Learning rate
lr = 0.05

# Standard deviation of initial parameters
passive_sd = 0.2
active_sd = 0.02

# The gamma parameter in the penalty function, given by the reference paper.
norm_weight = 300

# Seeds for the RNG functions to be able to reproduce results.
tf.random.set_seed(137)
np.random.seed(137)

# Phase space circile restriciton radius.
alpha_clip = 5

save_folder_name = str(input_len) + '_inputs'

os.makedirs(save_folder_name, exist_ok=True)

# %% [markdown]
# ### Initialization of the classical encoder and decoder networks.

# %%
latent_dim = 2

class Autoencoder(Model):
  def __init__(self, latent_dim):
    super(Autoencoder, self).__init__()
    self.latent_dim = latent_dim   
    self.encoder = tf.keras.Sequential([
      layers.Dense(input_len, activation ="elu"),
      layers.Dense(5, activation="elu"),
      layers.Dense(5, activation="elu"),
      layers.Dense(4, activation="elu"),
      layers.Dense(3, activation="elu"),
      layers.Dense(latent_dim, activation="elu"),
    ])
    
    self.decoder = tf.keras.Sequential([
        layers.Dense(input_len, activation="elu"),
        layers.Dense(3, activation="elu"),
        layers.Dense(4, activation="elu"),
        layers.Dense(5, activation="elu"),
        layers.Dense(input_len, activation="elu")
    ])
    

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

# %%
autoencoder = Autoencoder(latent_dim)
# Out:
# 2022-07-03 15:22:14.854200: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-07-03 15:22:14.854229: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-07-03 15:22:14.854250: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (BartuDesktop): /proc/driver/nvidia/version does not exist
# 2022-07-03 15:22:14.854482: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def GenerateTargetState(input_len, f):
    state = np.zeros(input_len)
    state[f] = 1.0
    train = np.array([state])
    return train, state
    
    
x_train, target_state = GenerateTargetState(input_len, train_state_select)
print('The target state for the training is chosen to be ' + str(target_state))
# Out:
# The target state for the training is chosen to be [0. 0. 0. 0. 1.]

# %% [markdown]
# ### Compile the classical autoencoder.

# %%
autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

# %% [markdown]
# ### Train the classical autoencoder and obtain the latent space.

# %%
history = autoencoder.fit(x_train, x_train,
                epochs=300,
                validation_data=(x_train, x_train))
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 739ms/step - loss: 0.1666 - val_loss: 0.1613
# Epoch 2/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1613 - val_loss: 0.1560
# Epoch 3/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1560 - val_loss: 0.1509
# Epoch 4/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1509 - val_loss: 0.1459
# Epoch 5/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1459 - val_loss: 0.1410
# Epoch 6/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1410 - val_loss: 0.1362
# Epoch 7/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1362 - val_loss: 0.1315
# Epoch 8/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1315 - val_loss: 0.1269
# Epoch 9/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1269 - val_loss: 0.1225
# Epoch 10/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1225 - val_loss: 0.1182
# Epoch 11/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1182 - val_loss: 0.1141
# Epoch 12/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1141 - val_loss: 0.1102
# Epoch 13/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.1102 - val_loss: 0.1063
# Epoch 14/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1063 - val_loss: 0.1027
# Epoch 15/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.1027 - val_loss: 0.0992
# Epoch 16/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0992 - val_loss: 0.0958
# Epoch 17/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0958 - val_loss: 0.0926
# Epoch 18/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0926 - val_loss: 0.0895
# Epoch 19/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0895 - val_loss: 0.0866
# Epoch 20/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0866 - val_loss: 0.0837
# Epoch 21/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0837 - val_loss: 0.0810
# Epoch 22/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0810 - val_loss: 0.0784
# Epoch 23/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0784 - val_loss: 0.0759
# Epoch 24/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0759 - val_loss: 0.0735
# Epoch 25/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0735 - val_loss: 0.0711
# Epoch 26/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0711 - val_loss: 0.0689
# Epoch 27/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0689 - val_loss: 0.0667
# Epoch 28/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0667 - val_loss: 0.0645
# Epoch 29/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0645 - val_loss: 0.0625
# Epoch 30/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0625 - val_loss: 0.0605
# Epoch 31/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0605 - val_loss: 0.0585
# Epoch 32/300
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0585 - val_loss: 0.0566
# Epoch 33/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0566 - val_loss: 0.0548
# Epoch 34/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0548 - val_loss: 0.0530
# Epoch 35/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0530 - val_loss: 0.0513
# Epoch 36/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0513 - val_loss: 0.0497
# Epoch 37/300
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0497 - val_loss: 0.0480
# Epoch 38/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0480 - val_loss: 0.0465
# Epoch 39/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0465 - val_loss: 0.0449
# Epoch 40/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0449 - val_loss: 0.0434
# Epoch 41/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0434 - val_loss: 0.0420
# Epoch 42/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0420 - val_loss: 0.0406
# Epoch 43/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0406 - val_loss: 0.0392
# Epoch 44/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0392 - val_loss: 0.0378
# Epoch 45/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0378 - val_loss: 0.0365
# Epoch 46/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0365 - val_loss: 0.0352
# Epoch 47/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0352 - val_loss: 0.0340
# Epoch 48/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0340 - val_loss: 0.0327
# Epoch 49/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0327 - val_loss: 0.0316
# Epoch 50/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0316 - val_loss: 0.0304
# Epoch 51/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0304 - val_loss: 0.0293
# Epoch 52/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0293 - val_loss: 0.0282
# Epoch 53/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0282 - val_loss: 0.0272
# Epoch 54/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0272 - val_loss: 0.0261
# Epoch 55/300
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0261 - val_loss: 0.0251
# Epoch 56/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0251 - val_loss: 0.0242
# Epoch 57/300
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0242 - val_loss: 0.0232
# Epoch 58/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0232 - val_loss: 0.0223
# Epoch 59/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0223 - val_loss: 0.0214
# Epoch 60/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0214 - val_loss: 0.0206
# Epoch 61/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0206 - val_loss: 0.0197
# Epoch 62/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0197 - val_loss: 0.0189
# Epoch 63/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0189 - val_loss: 0.0181
# Epoch 64/300
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0181 - val_loss: 0.0174
# Epoch 65/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0174 - val_loss: 0.0166
# Epoch 66/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0166 - val_loss: 0.0159
# Epoch 67/300
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0159 - val_loss: 0.0152
# Epoch 68/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0152 - val_loss: 0.0146
# Epoch 69/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0146 - val_loss: 0.0139
# Epoch 70/300
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0139 - val_loss: 0.0133
# Epoch 71/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0133 - val_loss: 0.0127
# Epoch 72/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0127 - val_loss: 0.0121
# Epoch 73/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0121 - val_loss: 0.0115
# Epoch 74/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0115 - val_loss: 0.0109
# Epoch 75/300
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0109 - val_loss: 0.0104
# Epoch 76/300
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0104 - val_loss: 0.0099
# Epoch 77/300
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0099 - val_loss: 0.0094
# Epoch 78/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0094 - val_loss: 0.0089
# Epoch 79/300
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0089 - val_loss: 0.0084
# Epoch 80/300
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0084 - val_loss: 0.0080
# Epoch
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
print(encoded_st)
np.savetxt(save_folder_name +'/encoded_ '+ str(train_state_select) +'.txt', encoded_st)
# Out:
# [[ 0.9403157  -0.31412214]]

# %%
import strawberryfields as sf
from strawberryfields import ops
sf.about()
# Out:
# Strawberry Fields: a Python library for continuous-variable quantum circuits.
# Copyright 2018-2020 Xanadu Quantum Technologies Inc.
#
# Python version:            3.10.4
# Platform info:             Linux-5.4.0-121-generic-x86_64-with-glibc2.31
# Installation path:         /home/bartu/miniconda3/envs/qml/lib/python3.10/site-packages/strawberryfields
# Strawberry Fields version: 0.23.0
# Numpy version:             1.22.4
# Scipy version:             1.8.1
# SymPy version:             1.10.1
# NetworkX version:          2.8.4
# The Walrus version:        0.19.0
# Blackbird version:         0.4.0
# XCC version:               0.2.1
# TensorFlow version:        2.9.1

# %%
def layer(params, q):
    """CV quantum neural network layer acting on ``N`` modes.

    Args:
        params (list[float]): list of length ``2*(max(1, N-1) + N**2 + n)`` containing
            the number of parameters for the layer
        q (list[RegRef]): list of Strawberry Fields quantum registers the layer
            is to be applied to
    """
    ops.Dgate(tf.clip_by_value(encoded_st[0][0], clip_value_min = -alpha_clip, clip_value_max = alpha_clip), encoded_st[0][1]) | q[0]
    
    N = len(q)
    M = int(N * (N - 1)) + max(1, N - 1)

    rphi = params[-N+1:]
    s = params[M:M+N]
    dr = params[2*M+N:2*M+2*N]
    dp = params[2*M+2*N:2*M+3*N]
    k = params[2*M+3*N:2*M+4*N]
    
    ops.Rgate(rphi[0]) | q[0]
    
    for i in range(N):
        ops.Sgate(s[i]) | q[i]

    ops.Rgate(rphi[0]) | q[0]

    for i in range(N):
        ops.Dgate(dr[i], dp[i]) | q[i]
        ops.Kgate(k[i]) | q[i]

# %% [markdown]
# ### Initialization of layer weights.

# %%
def init_weights(modes, layers, active_sd=0.0001, passive_sd=0.1):
    """Initialize a 2D TensorFlow Variable containing normally-distributed
    random weights for an ``N`` mode quantum neural network with ``L`` layers.

    Args:
        modes (int): the number of modes in the quantum neural network
        layers (int): the number of layers in the quantum neural network
        active_sd (float): the standard deviation used when initializing
            the normally-distributed weights for the active parameters
            (displacement, squeezing, and Kerr magnitude)
        passive_sd (float): the standard deviation used when initializing
            the normally-distributed weights for the passive parameters
            (beamsplitter angles and all gate phases)

    Returns:
        tf.Variable[tf.float32]: A TensorFlow Variable of shape
        ``[layers, 2*(max(1, modes-1) + modes**2 + modes)]``, where the Lth
        row represents the layer parameters for the Lth layer.
    """
    # Number of interferometer parameters:
    M = int(modes * (modes - 1)) + max(1, modes - 1)

    # Create the TensorFlow variables
    int1_weights = tf.random.normal(shape=[layers, M], stddev=passive_sd)
    s_weights = tf.random.normal(shape=[layers, modes], stddev=active_sd)
    int2_weights = tf.random.normal(shape=[layers, M], stddev=passive_sd)
    dr_weights = tf.random.normal(shape=[layers, modes], stddev=active_sd)
    dp_weights = tf.random.normal(shape=[layers, modes], stddev=passive_sd)
    k_weights = tf.random.normal(shape=[layers, modes], stddev=active_sd)

    weights = tf.concat(
        [int1_weights, s_weights, int2_weights, dr_weights, dp_weights, k_weights], axis=1
    )

    weights = tf.Variable(weights)

    return weights

# %%
# initialize engine and program
eng = sf.Engine(backend="tf", backend_options={"cutoff_dim": cutoff_dim})
qnn = sf.Program(modes)

# initialize QNN weights
weights = init_weights(modes, Qlayers) # our TensorFlow weights
num_params = np.prod(weights.shape)   # total number of parameters in our model

# %%
# Create array of Strawberry Fields symbolic gate arguments, matching
# the size of the weights Variable.
sf_params = np.arange(num_params).reshape(weights.shape).astype(np.str)
sf_params = np.array([qnn.params(*i) for i in sf_params])


# Construct the symbolic Strawberry Fields program by
# looping and applying layers to the program.
with qnn.context as q:
    for k in range(Qlayers):
        layer(sf_params[k], q)
# Out:
# /tmp/ipykernel_132500/2132937993.py:3: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### Definition of the quantum cost function.

# %%
def cost(weights):
    # Create a dictionary mapping from the names of the Strawberry Fields
    # free parameters to the TensorFlow weight values.
    mapping = {p.name: w for p, w in zip(sf_params.flatten(), tf.reshape(weights, [-1]))}

    # Run engine
    state = eng.run(qnn, args=mapping).state

    # Extract the statevector
    ket = state.ket()

    # Compute the fidelity between the output statevector
    # and the target state.
    fidelity = tf.abs(tf.reduce_sum(tf.math.conj(ket) * target_state)) ** 2

    # Objective function to minimize
    #cost = tf.abs(tf.reduce_sum(tf.math.conj(ket) * target_state) - 1)
    #return cost, fidelity, ket
    # Instead of the Cost function, maybe it is better to break it down to components
    # at least, when the Fock basis is insufficent, it will be visible
    difference = tf.reduce_sum(tf.abs(ket - target_state))
    fidelity = tf.abs(tf.reduce_sum(tf.math.conj(ket) * target_state)) ** 2
    return difference, fidelity, ket, tf.math.real(state.trace())

# %% [markdown]
# ### Optimizer definition.

# %%
opt = tf.keras.optimizers.Adam(learning_rate=lr)

# %% [markdown]
# ### Train the quantum decoder.

# %%
fid_progress = []
loss_progress = []
best_fid = 0

for i in range(reps):
    # reset the engine if it has already been executed
    if eng.run_progs:
        eng.reset()

    with tf.GradientTape() as tape:
        loss, fid, ket, trace = cost(weights)

    # Stores fidelity at each step
    fid_progress.append(fid.numpy())
    
    loss_progress.append(loss)

    if fid > best_fid:
        # store the new best fidelity and best state
        best_fid = fid.numpy()
        learnt_state = ket.numpy()

    # one repetition of the optimization
    gradients = tape.gradient(loss, weights)
    opt.apply_gradients(zip([gradients], [weights]))

    # Prints progress at every rep
    if i % 1 == 0:
        print("Rep: {} Cost: {:.4f} Fidelity: {:.4f} Trace: {:.4f}".format(i, loss, fid, trace))
# Out:
# Rep: 0 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 1 Cost: 1.0017 Fidelity: 0.0000 Trace: 0.0000
# Rep: 2 Cost: 1.0021 Fidelity: 0.0000 Trace: 0.0000
# Rep: 3 Cost: 1.0043 Fidelity: 0.0000 Trace: 0.0000
# Rep: 4 Cost: 1.0014 Fidelity: 0.0000 Trace: 0.0000
# Rep: 5 Cost: 1.0005 Fidelity: 0.0000 Trace: 0.0000
# Rep: 6 Cost: 1.0012 Fidelity: 0.0000 Trace: 0.0000
# Rep: 7 Cost: 1.0025 Fidelity: 0.0000 Trace: 0.0000
# Rep: 8 Cost: 1.0006 Fidelity: 0.0000 Trace: 0.0000
# Rep: 9 Cost: 1.0019 Fidelity: 0.0000 Trace: 0.0000
# Rep: 10 Cost: 1.0014 Fidelity: 0.0000 Trace: 0.0000
# Rep: 11 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep:
Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 214 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 215 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 216 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 217 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 218 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 219 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 220 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 221 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 222 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 223 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 224 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 225 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 226 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 227 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 228 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 229 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 230 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 231 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 232 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 233 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 234 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 235 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 236 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 237 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 238 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 239 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 240 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 241 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 242 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 243 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 244 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 245 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 246 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 247 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 248 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 249 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 250 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 251 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 252 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 253 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 254 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 255 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 256 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 257 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 258 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 259 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 260 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 261 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 262 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 263 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 264 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 265 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 266 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 267 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 268 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 269 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 270 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 271 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 272 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 273 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 274 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 275 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 276 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 277 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 278 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 279 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 280 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 281 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 282 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 283 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 284 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 285 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 286 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 287 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 288 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 289 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 290 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 291 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 292 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 293 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 294 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 295 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 296 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 297 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 298 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 299 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 300 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 301 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 302 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 303 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 304 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 305 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 306 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 307 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 308 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 309 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 310 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 311 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 312 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 313 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 314 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 315 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 316 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 317 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 318 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 319 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 320 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 321 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 322 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 323 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 324 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 325 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 326 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 327 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 328 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 329 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 330 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 331 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 332 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 333 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 334 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 335 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 336 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 337 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 338 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 339 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 340 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 341 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 342 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 343 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 344 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 345 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 346 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 347 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 348 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 349 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 350 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 351 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 352 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 353 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 354 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 355 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 356 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 357 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 358 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 359 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 360 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 361 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 362 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 363 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 364 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 365 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 366 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 367 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 368 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 369 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 370 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 371 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 372 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 373 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 374 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 375 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 376 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 377 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 378 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 379 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 380 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 381 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 382 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 383 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 384 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 385 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 386 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 387 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 388 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 389 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 390 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 391 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 392 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 393 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 394 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 395 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 396 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 397 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 398 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 399 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 400 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 401 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 402 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 403 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 404 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 405 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 406 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 407 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 408 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 409 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 410 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 411 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 412 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 413 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 414 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 415 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 416 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 417 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 418 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 419 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 420 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 421 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 422 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 423 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 424 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 425 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 426 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 427 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 428 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 429 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 430 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 431 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 432 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 433 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 434 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 435 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 436 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 437 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 438 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 439 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 440 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 441 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 442 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 443 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 444 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 445 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 446 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 447 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 448 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 449 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 450 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 451 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 452 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 453 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 454 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 455 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 456 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 457 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 458 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 459 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 460 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 461 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 462 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 463 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 464 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 465 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 466 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 467 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 468 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 469 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 470 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 471 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 472 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 473 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 474 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 475 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 476 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 477 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 478 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 479 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 480 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 481 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 482 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 483 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 484 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 485 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 486 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 487 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 488 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 489 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 490 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 491 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 492 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 493 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 494 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 495 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 496 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 497 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 498 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000
# Rep: 499 Cost: 1.0000 Fidelity: 0.0000 Trace: 0.0000

# %% [markdown]
# ### Produce fidelity plot.

# %%
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

fig, ax = plt.subplots(figsize=(12, 6), dpi = 100)

# Set tick font size
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.plot(fid_progress, linewidth = 3)
plt.ylabel("Fidelity", fontsize = '16')
ax.yaxis.set_ticks(np.arange(0, 1, 0.4))
plt.xlabel("Epoch", fontsize = '16')
ax.xaxis.set_ticks(np.arange(0, reps, 200))
plt.title('STM Fidelity', fontsize = '20')


plt.savefig('STM_fidelity.png')

# %% [markdown]
# ### Produce loss plot.

# %%
fig, ax = plt.subplots(figsize=(12, 12), dpi = 100)

# Set tick font size
for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

plt.plot(loss_progress, linewidth = 3)
plt.ylabel("Training Loss", fontsize = '20')
ax.yaxis.set_ticks(np.arange(0, 1, 0.4))
plt.xlabel("Epoch", fontsize = '20')
ax.xaxis.set_ticks(np.arange(0, reps, 200))
plt.title('STM Training Loss', fontsize = '24')


plt.savefig('STM_loss.png')

# %% [markdown]
# ### Definition of the function that plots Wigner functions.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


def wigner(rho):
    """This code is a modified version of the 'iterative' method
    of the wigner function provided in QuTiP, which is released
    under the BSD license, with the following copyright notice:

    Copyright (C) 2011 and later, P.D. Nation, J.R. Johansson,
    A.J.G. Pitchford, C. Granade, and A.L. Grimsmo.

    All rights reserved."""
    import copy

    # Domain parameter for Wigner function plots
    l = 5.0
    cutoff = rho.shape[0]

    # Creates 2D grid for Wigner function plots
    x = np.linspace(-l, l, 100)
    p = np.linspace(-l, l, 100)

    Q, P = np.meshgrid(x, p)
    A = (Q + P * 1.0j) / (2 * np.sqrt(2 / 2))

    Wlist = np.array([np.zeros(np.shape(A), dtype=complex) for k in range(cutoff)])

    # Wigner function for |0><0|
    Wlist[0] = np.exp(-2.0 * np.abs(A) ** 2) / np.pi

    # W = rho(0,0)W(|0><0|)
    W = np.real(rho[0, 0]) * np.real(Wlist[0])

    for n in range(1, cutoff):
        Wlist[n] = (2.0 * A * Wlist[n - 1]) / np.sqrt(n)
        W += 2 * np.real(rho[0, n] * Wlist[n])

    for m in range(1, cutoff):
        temp = copy.copy(Wlist[m])
        # Wlist[m] = Wigner function for |m><m|
        Wlist[m] = (2 * np.conj(A) * temp - np.sqrt(m) * Wlist[m - 1]) / np.sqrt(m)

        # W += rho(m,m)W(|m><m|)
        W += np.real(rho[m, m] * Wlist[m])

        for n in range(m + 1, cutoff):
            temp2 = (2 * A * Wlist[n - 1] - np.sqrt(m) * temp) / np.sqrt(n)
            temp = copy.copy(Wlist[n])
            # Wlist[n] = Wigner function for |m><n|
            Wlist[n] = temp2

            # W += rho(m,n)W(|m><n|) + rho(n,m)W(|n><m|)
            W += 2 * np.real(rho[m, n] * Wlist[n])

    return Q, P, W / 2

# %% [markdown]
# ### Obtain the target and learnt states from the quantum decoder.

# %%
rho_target = np.outer(target_state, target_state.conj())
rho_learnt = np.outer(learnt_state, learnt_state.conj())

# %% [markdown]
# ### Plot the target state as a Wigner function.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
X, P, W = wigner(rho_target)
ax.plot_surface(X, P, W, cmap="RdYlGn", lw=0.5, rstride=1, cstride=1)
ax.contour(X, P, W, 10, cmap="RdYlGn", linestyles="solid", offset=-0.17)
ax.set_axis_off()
fig.show()
# Out:
# /tmp/ipykernel_132500/1595207717.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# ### Plot the learnt state as a Wigner function.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
X, P, W = wigner(rho_learnt)
ax.plot_surface(X, P, W, cmap="RdYlGn", lw=0.5, rstride=1, cstride=1)
ax.contour(X, P, W, 10, cmap="RdYlGn", linestyles="solid", offset=-0.17)
ax.set_axis_off()
fig.show()
# Out:
# /tmp/ipykernel_132500/4117463628.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
np.savetxt(save_folder_name + '/x' + str(train_state_select) + '.txt', X)
np.savetxt(save_folder_name + '/p' + str(train_state_select) + '.txt', P)
np.savetxt(save_folder_name + '/w' + str(train_state_select) + '.txt', W)
